# %%
import pandas as pd

# %%
import chardet
file = 'DataCoSupplyChainDataset.csv'
with open(file, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
df = pd.read_csv(file, sep=',',encoding ='ISO-8859-1')
df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# ...

# %%
df.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

# %%
customer = df[['Customer Id','Customer Segment','Customer City','Customer State','Customer Country','Customer Street']]
customer.head()
# Out:
#    Customer Id Customer Segment Customer City Customer State Customer Country  \
# 0        20755         Consumer        Caguas             PR      Puerto Rico
# 1        19492         Consumer        Caguas             PR      Puerto Rico
# 2        19491         Consumer      San Jose             CA          EE. UU.
# 3        19490      Home Office   Los Angeles             CA          EE. UU.
# 4        19489        Corporate        Caguas             PR      Puerto Rico
#
#             Customer Street
# 0  5365 Noble Nectar Island
# 1          2679 Rustic Loop
# 2      8510 Round Bear Gate
# 3           3200 Amber Bend
# 4  8671 Iron Anchor Corners

# %%
orders = df[['Order Id','Order Customer Id','order date (DateOrders)','Order Status','Order City','Order State','Order Country','Order Region','Market','shipping date (DateOrders)']]
orders.head()
# Out:
#    Order Id  Order Customer Id order date (DateOrders)     Order Status  \
# 0     77202              20755         1/31/2018 22:56         COMPLETE
# 1     75939              19492         1/13/2018 12:27          PENDING
# 2     75938              19491         1/13/2018 12:06           CLOSED
# 3     75937              19490         1/13/2018 11:45         COMPLETE
# 4     75936              19489         1/13/2018 11:24  PENDING_PAYMENT
#
#    Order City      Order State Order Country    Order Region        Market  \
# 0      Bekasi  Java Occidental     Indonesia  Southeast Asia  Pacific Asia
# 1     Bikaner         Rajastán         India      South Asia  Pacific Asia
# 2     Bikaner         Rajastán         India      South Asia  Pacific Asia
# 3  Townsville       Queensland     Australia         Oceania  Pacific Asia
# 4  Townsville       Queensland     Australia         Oceania  Pacific Asia
#
#   shipping date (DateOrders)
# 0             2/3/2018 22:56
# ...

# %%
products = df.filter(like='Product', axis=1)
products.head()
# Out:
#    Order Item Product Price  Product Card Id  Product Category Id  \
# 0                    327.75             1360                   73
# 1                    327.75             1360                   73
# 2                    327.75             1360                   73
# 3                    327.75             1360                   73
# 4                    327.75             1360                   73
#
#    Product Description                                 Product Image  \
# 0                  NaN  http://images.acmesports.sports/Smart+watch
# 1                  NaN  http://images.acmesports.sports/Smart+watch
# 2                  NaN  http://images.acmesports.sports/Smart+watch
# 3                  NaN  http://images.acmesports.sports/Smart+watch
# 4                  NaN  http://images.acmesports.sports/Smart+watch
#
#    Product Name  Product Price  Product Status
# 0  Smart watch          327.75               0
# 1  Smart watch          327.75               0
# ...

# %%
categories = df.filter(like='Category',axis=1)

# %%
categories = categories[categories.duplicated()==False].set_index('Category Id').iloc[:,:-1].sort_index()

# %%
categories.head()
# Out:
#                    Category Name
# Category Id
# 2                         Soccer
# 3            Baseball & Softball
# 4                     Basketball
# 5                       Lacrosse
# 6               Tennis & Racquet
